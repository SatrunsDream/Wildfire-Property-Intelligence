# %%
# Colab drive mount (optional - skip if running locally)
try:
    from google.colab import drive
    drive.mount("/content/drive")
except ModuleNotFoundError:
    pass  # Running locally, not in Colab

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import seaborn as sns
from scipy.spatial.distance import jensenshannon
import geopandas as gpd
import urllib.request, zipfile
from matplotlib.colors import LinearSegmentedColormap

# %%
# Data path: try Colab (group member) first, then local project paths
from pathlib import Path
DF_FILENAME = "Capstone2025_nsi_lvl9_with_landcover_and_color.csv.gz"
candidates = [
    "/content/drive/MyDrive/Capstone/" + DF_FILENAME,  # Colab (group member)
]
PROJECT_ROOT = Path.cwd()
for _ in range(6):
    if (PROJECT_ROOT / "dataset").exists() or (PROJECT_ROOT / "website").exists():
        break
    PROJECT_ROOT = PROJECT_ROOT.parent
DATA_DIR = PROJECT_ROOT / "dataset" if (PROJECT_ROOT / "dataset").exists() else PROJECT_ROOT / "website" / "backend" / "data"
candidates.extend([str(DATA_DIR / DF_FILENAME), str(DATA_DIR / DF_FILENAME.replace(".gz", ""))])
df_path = None
for p in candidates:
    if Path(p).exists():
        df_path = p
        break
if df_path is None:
    raise FileNotFoundError(f"Data file not found. Tried: {candidates}")
df = pd.read_csv(df_path)
print(f"Loaded from: {df_path}")
df.head()
# Out:
# Loaded from: c:\Users\sardo\OneDrive\Desktop\Classes\Wildfire-Property-Intelligence\dataset\Capstone2025_nsi_lvl9_with_landcover_and_color.csv.gz
#                 h3  fips st_damcat bldgtype     lc_type  \
# 0  8929a960d6fffff  6047       RES        M  urban+crop
# 1  8929a978c07ffff  6047       RES        M  urban+crop
# 2  892836da147ffff  6047       RES        M  urban+crop
# 3  892836c644fffff  6047       RES        M  urban+crop
# 4  892836d736fffff  6047       RES        M  urban+crop
#
#                                          loc     clr  clr_cc
# 0  POINT(-120.828147398273 37.0724076637771)  orange       8
# 1   POINT(-120.63428156983 36.9838900827867)  orange       8
# 2  POINT(-120.464731172229 37.3234892623252)  orange      11
# 3  POINT(-120.787252301526 37.4298893882365)  orange      12
# 4  POINT(-120.716239893409 37.3391233398179)  orange       1

# %% [markdown]
# # Framework: Group-Level Distributional Anomaly Detection (Divergence-Based)

# %%
county_lc_color = df.groupby(['fips', 'lc_type', 'clr'])['clr_cc'].sum().reset_index(name='count')
county_lc_totals = df.groupby(['fips', 'lc_type'])['clr_cc'].sum().reset_index(name='total')
county_lc_color = county_lc_color.merge(county_lc_totals, on=['fips', 'lc_type'])
county_lc_color['proportion'] = county_lc_color['count'] / county_lc_color['total']

county_lc_color.head(20)
# Out:
#     fips lc_type        clr  count  total  proportion
# 0   6001  forest  alabaster    891  10026    0.088869
# 1   6001  forest      amber    579  10026    0.057750
# 2   6001  forest      cocoa   3656  10026    0.364652
# 3   6001  forest      green   1843  10026    0.183822
# 4   6001  forest       grey      1  10026    0.000100
# 5   6001  forest     indigo      1  10026    0.000100
# 6   6001  forest       navy   1063  10026    0.106024
# 7   6001  forest     orange   1213  10026    0.120985
# 8   6001  forest        red    779  10026    0.077698
# 9   6001   grass  alabaster      9     34    0.264706
# 10  6001   grass      cocoa     12     34    0.352941
# 11  6001   grass      green      3     34    0.088235
# 12  6001   grass       grey      1     34    0.029412
# 13  6001   grass       navy      3     34    0.088235
# 14  6001   grass     orange      3     34    0.088235
# 15  6001   grass        red      3     34    0.088235
# 16  6001   shrub  alabaster    408   2586    0.157773
# 17  6001   shrub      amber    182   2586    0.070379
# 18  6001   shrub      cocoa    896   2586    0.346481
# 19  6001   shrub      green    227   2586    0.087780

# %%
# from eda
# color distribution conditioned on landcover -- for each lc, what is the color distribution?

color_by_lc = df.groupby(['lc_type', 'clr'])['clr_cc'].sum().unstack(fill_value=0)
color_by_lc = color_by_lc.div(color_by_lc.sum(axis=1), axis=0)
color_by_lc
# Out:
# clr           alabaster     amber      aqua  aquamarine    auburn     azure  \
# lc_type
# barren         0.102273  0.041921  0.001982    0.008519  0.000084  0.001898
# crop           0.226058  0.007698  0.002706    0.011456  0.000120  0.020086
# forest         0.078258  0.010738  0.003359    0.002538  0.000002  0.006177
# grass          0.240379  0.026827  0.002068    0.001128  0.000000  0.019932
# other          0.000000  0.000000  0.000000    0.000000  0.000000  0.000000
# shrub          0.100819  0.023163  0.005601    0.002252  0.000000  0.024789
# urban          0.053622  0.051934  0.000103    0.000038  0.000817  0.015710
# urban+barren   0.085809  0.108148  0.000912    0.000608  0.000028  0.000668
# urban+crop     0.081917  0.045936  0.004422    0.009249  0.000309  0.028559
# urban+forest   0.057175  0.032248  0.001207    0.000270  0.000066  0.004630
# urban+grass    0.094429  0.069323  0.003018    0.000662  0.000054  0.021290
# urban+other    0.060134  0.069042  0.008909    0.000000  0.000000  0.013363
# urban+shrub    0.063448  0.064741  0.001105    0.000331  0.000139  0.009188
#
# clr                bar     beige      blue     brown  ...      plum    purple  \
# lc_type                                               ...
# barren        0.000084  0.009911  0.000801  0.006495  ...  0.000253  0.017292
# crop          0.014734  0.007848  0.007066  0.146165  ...  0.000361  0.014884
# forest        0.000550  0.007171  0.008072  0.202637  ...  0.000051  0.005919
# grass         0.003573  0.009151  0.002068  0.060925  ...  0.000501  0.011345
# other         0.000000  0.000000  0.000000  1.000000  ...  0.000000  0.000000
# shrub         0.001148  0.019942  0.013185  0.129642  ...  0.000224  0.006704
# urban         0.000225  0.009185  0.007013  0.022942  ...  0.000331  0.040057
# urban+barren  0.000007  0.005137  0.001456  0.003187  ...  0.000163  0.061133
# urban+crop    0.001191  0.005290  0.007566  0.145122  ...  0.000926  0.037373
# urban+forest  0.001518  0.004211  0.006121  0.179064  ...  0.000671  0.010979
# urban+grass   0.000565  0.002315  0.013402  0.149358  ...  0.000221  0.033920
# urban+other   0.000000  0.000000  0.000000  0.008909  ...  0.000000  0.040089
# urban+shrub   0.000139  0.006669  0.003857  0.032268  ...  0.000174  0.048170
#
# clr                red      sage   scarlet    sienna       tan  terracotta  \
# lc_type
# barren        0.069293  0.002488  0.000000  0.001307  0.000000    0.004007
# crop          0.015726  0.034519  0.000150  0.003608  0.001082    0.018643
# forest        0.009758  0.062577  0.000004  0.000778  0.004199    0.032895
# grass         0.027391  0.018052  0.000000  0.000752  0.001567    0.028018
# other         0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# shrub         0.040286  0.036445  0.000015  0.003363  0.004064    0.035431
# urban         0.062294  0.008774  0.002501  0.003615  0.000000    0.077469
# urban+barren  0.142423  0.001180  0.000049  0.000922  0.000000    0.009698
# urban+crop    0.055620  0.038822  0.002050  0.016561  0.000203    0.067317
# urban+forest  0.024936  0.046583  0.000227  0.001784  0.000749    0.079637
# urban+grass   0.067113  0.043960  0.000146  0.005412  0.000975    0.076564
# urban+other   0.073497  0.002227  0.000000  0.006682  0.000000    0.075724
# urban+shrub   0.066967  0.009488  0.000244  0.003021  0.000383    0.084873
#
# clr              verde    yellow
# lc_type
# barren        0.000000  0.000337
# crop          0.001323  0.000000
# forest        0.022647  0.000000
# grass         0.002068  0.000000
# other         0.000000  0.000000
# shrub         0.004698  0.000157
# urban         0.000000  0.000068
# urban+barren  0.000000  0.000226
# urban+crop    0.003305  0.006531
# urban+forest  0.010310  0.000244
# urban+grass   0.001078  0.002559
# urban+other   0.000000  0.004454
# urban+shrub   0.000690  0.000585
#
# [13 rows x 38 columns]

# %%
# this is the "normal" for each lc -- use as baseline
color_by_lc.head()
# Out:
# clr      alabaster     amber      aqua  aquamarine    auburn     azure  \
# lc_type
# barren    0.102273  0.041921  0.001982    0.008519  0.000084  0.001898
# crop      0.226058  0.007698  0.002706    0.011456  0.000120  0.020086
# forest    0.078258  0.010738  0.003359    0.002538  0.000002  0.006177
# grass     0.240379  0.026827  0.002068    0.001128  0.000000  0.019932
# other     0.000000  0.000000  0.000000    0.000000  0.000000  0.000000
#
# clr           bar     beige      blue     brown  ...      plum    purple  \
# lc_type                                          ...
# barren   0.000084  0.009911  0.000801  0.006495  ...  0.000253  0.017292
# crop     0.014734  0.007848  0.007066  0.146165  ...  0.000361  0.014884
# forest   0.000550  0.007171  0.008072  0.202637  ...  0.000051  0.005919
# grass    0.003573  0.009151  0.002068  0.060925  ...  0.000501  0.011345
# other    0.000000  0.000000  0.000000  1.000000  ...  0.000000  0.000000
#
# clr           red      sage   scarlet    sienna       tan  terracotta  \
# lc_type
# barren   0.069293  0.002488  0.000000  0.001307  0.000000    0.004007
# crop     0.015726  0.034519  0.000150  0.003608  0.001082    0.018643
# forest   0.009758  0.062577  0.000004  0.000778  0.004199    0.032895
# grass    0.027391  0.018052  0.000000  0.000752  0.001567    0.028018
# other    0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
#
# clr         verde    yellow
# lc_type
# barren   0.000000  0.000337
# crop     0.001323  0.000000
# forest   0.022647  0.000000
# grass    0.002068  0.000000
# other    0.000000  0.000000
#
# [5 rows x 38 columns]

# %%
# function to compute Jenson-Shannon divergence between county+lc and baseline
def compute_divergence(county_fips, lc_type, county_data, baseline):
    # get county's color distribution for given lc
    county_colors = county_data[(county_data['fips'] == county_fips) & (county_data['lc_type'] == lc_type)]

    # convert to same format as reference (all colors present)
    county_dist = pd.Series(0.0, index=baseline.columns)
    for _, row in county_colors.iterrows():
        county_dist[row['clr']] = row['proportion']

    # get baseline distribution for given lc
    b_dist = baseline.loc[lc_type]

    # compute js divergence
    divergence = jensenshannon(county_dist, b_dist)

    return divergence

# %%
compute_divergence(6073, 'forest', county_lc_color, color_by_lc)
# Out:
# 0.581494985757395

# %%
# get all unique county+lc combos
county_lc_groups = county_lc_color[['fips', 'lc_type']].drop_duplicates()

divergences = []
for _, row in county_lc_groups.iterrows():
    fips = row['fips']
    lc = row['lc_type']

    div = compute_divergence(fips, lc, county_lc_color, color_by_lc)
    divergences.append({
        'fips': fips,
        'lc_type': lc,
        'divergence': div
    })

divergence_df = pd.DataFrame(divergences)
print(f"{len(divergence_df)} divergence scores")
divergence_df.head(10)
# Out:
# 470 divergence scores
#    fips       lc_type  divergence
# 0  6001        forest    0.565040
# 1  6001         grass    0.377538
# 2  6001         shrub    0.431759
# 3  6001         urban    0.404665
# 4  6001  urban+barren    0.171058
# 5  6001    urban+crop    0.536547
# 6  6001  urban+forest    0.521550
# 7  6001   urban+grass    0.472593
# 8  6001   urban+other    0.429312
# 9  6001   urban+shrub    0.394256

# %%
divergence_df['divergence'].mean(), divergence_df['divergence'].min(), divergence_df['divergence'].max()
# Out:
# (0.5757209432836554, 0.0, 0.8111161540284432)

# %%
plt.figure(figsize=(10, 6))
plt.hist(divergence_df['divergence'], bins=30, edgecolor='black', alpha=0.7)
plt.xlabel('Jensen-Shannon Divergence')
plt.ylabel('Count')
plt.title('Distribution of Divergence Scores (County × Landcover)')
plt.axvline(divergence_df['divergence'].median(), color='red', linestyle='--', label=f'Median: {divergence_df["divergence"].median():.3f}')
plt.legend()
plt.show()

# %%
# top 10% anomalous
threshold = divergence_df['divergence'].quantile(0.9)
divergence_df['anomalous'] = divergence_df['divergence'] >= threshold

print(f"Threshold for top 10%: {threshold:.3f}")
print(f"Number of anomalous groups: {divergence_df['anomalous'].sum()}")

# top 20 anomalous
divergence_df.nlargest(20, 'divergence')
# Out:
# Threshold for top 10%: 0.704
# Number of anomalous groups: 47
#      fips       lc_type  divergence  anomalous
# 53   6013   urban+other    0.811116       True
# 98   6027          crop    0.809519       True
# 223  6057         shrub    0.785089       True
# 173  6043         grass    0.777787       True
# 11   6003         shrub    0.770173       True
# 37   6011         grass    0.766375       True
# 189  6049         grass    0.766375       True
# 84   6023  urban+barren    0.761581       True
# 132  6033    urban+crop    0.760526       True
# 41   6011   urban+grass    0.755588       True
# 372  6091         shrub    0.753574       True
# 195  6051        barren    0.743780       True
# 218  6055    urban+crop    0.742397       True
# 250  6063   urban+shrub    0.739584       True
# 174  6043         shrub    0.737094       True
# 158  6039         grass    0.736919       True
# 38   6011         shrub    0.733107       True
# 176  6043   urban+shrub    0.732569       True
# 192  6049  urban+forest    0.729582       True
# 188  6049        forest    0.728213       True

# %%
county_anomaly_counts = divergence_df[divergence_df['anomalous']].groupby('fips').size().reset_index(name='num_anomalies')

county_avg_div = divergence_df.groupby('fips')['divergence'].mean().reset_index(name='avg_divergence')

county_summary = county_anomaly_counts.merge(county_avg_div, on='fips', how='right')
county_summary['num_anomalies'] = county_summary['num_anomalies'].fillna(0)
county_summary.head(5)
# Out:
#    fips  num_anomalies  avg_divergence
# 0  6001            0.0        0.430432
# 1  6003            3.0        0.724331
# 2  6005            1.0        0.664166
# 3  6007            0.0        0.544815
# 4  6009            0.0        0.627632

# %%
import geopandas as gpd

# load ca counties
url = "https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json"
counties_gdf = gpd.read_file(url)

# filter out califoria (fips starting with 06)
ca_counties = counties_gdf[counties_gdf['STATE'] == '06'].copy()
ca_counties['fips'] = ca_counties['id'].astype(int)

ca_counties = ca_counties.merge(county_summary, on='fips', how='left')

fig, ax = plt.subplots(1, 1, figsize=(12, 10))
ca_counties.plot(column='num_anomalies', cmap='YlOrRd', legend=True, ax=ax,
                 edgecolor='black', linewidth=0.5, missing_kwds={'color': 'lightgrey'})
plt.title('Number of Anomalous Landcover Groups by County')
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
import plotly.express as px

ca_counties_plotly = ca_counties.drop(columns=['num_anomalies', 'avg_divergence'], errors='ignore')
ca_counties_plotly = ca_counties_plotly.merge(county_summary, on='fips', how='left')

# interactive choropleth
fig = px.choropleth(ca_counties_plotly,
                    geojson=ca_counties_plotly.geometry,
                    locations=ca_counties_plotly.index,
                    color='num_anomalies',
                    hover_data=['fips', 'num_anomalies', 'avg_divergence'],
                    color_continuous_scale='YlOrRd',
                    title='Anomalous Landcover Groups by County (interactive)')

fig.update_geos(fitbounds="locations", visible=False)
fig.update_layout(height=700)
fig.show()

# %%
# look at 6027's anomalies
county_6027 = divergence_df[(divergence_df['fips'] == 6027) & (divergence_df['anomalous'])]
print(f"County 6027 anomalous groups:")
print(county_6027.sort_values('divergence', ascending=False))

# for each anomalous landcover, show the actual vs baseline distributions
for _, row in county_6027.iterrows():
    lc = row['lc_type']
    print(f"\n{'='*60}")
    print(f"LANDCOVER: {lc} (divergence: {row['divergence']:.3f})")
    print(f"{'='*60}")

    county_colors = county_lc_color[(county_lc_color['fips'] == 6027) &
                                     (county_lc_color['lc_type'] == lc)]

    baseline_dist = color_by_lc.loc[lc]

    # Compare top colors
    print("\nCounty's top colors:")
    print(county_colors.nlargest(5, 'proportion')[['clr', 'proportion', 'count']])

    print("\nBaseline's top colors:")
    baseline_top = baseline_dist.nlargest(5)
    print(baseline_top)
# Out:
# County 6027 anomalous groups:
#      fips       lc_type  divergence  anomalous
# 98   6027          crop    0.809519       True
# 97   6027        barren    0.723923       True
# 103  6027    urban+crop    0.714181       True
# 101  6027         shrub    0.706605       True
# 102  6027  urban+barren    0.706027       True
#
# ============================================================
# LANDCOVER: barren (divergence: 0.724)
# ============================================================
#
# County's top colors:
#         clr  proportion  count
# 900   beige    0.427350    150
# 901  coffee    0.133903     47
# 908  orange    0.133903     47
# 899    aqua    0.111111     39
# 904   ivory    0.071225     25
#
# Baseline's top colors:
# clr
# cocoa        0.413690
# orange       0.122264
# alabaster    0.102273
# navy         0.101978
# red          0.069293
# Name: barren, dtype: float64
#
# ============================================================
# LANDCOVER: crop (divergence: 0.810)
# ============================================================
#
# County's top colors:
#        clr  proportion  count
# 911  beige         0.5      1
# 912  ivory         0.5      1
#
# Baseline's top colors:
# clr
# alabaster    0.226058
# brown        0.146165
# cocoa        0.135641
# coffee       0.062393
# gray         0.058063
# Name: crop, dtype: float64
#
# ============================================================
# LANDCOVER: shrub (divergence: 0.707)
# ============================================================
#
# County's top colors:
#         clr  proportion  count
# 933   beige    0.436590    210
# 936   ivory    0.168399     81
# 932    aqua    0.108108     52
# 937   lilac    0.108108     52
# 939  orange    0.108108     52
#
# Baseline's top colors:
# clr
# cocoa        0.255123
# brown        0.129642
# alabaster    0.100819
# navy         0.055984
# orange       0.051554
# Name: shrub, dtype: float64
#
# ============================================================
# LANDCOVER: urban+barren (divergence: 0.706)
# ============================================================
#
# County's top colors:
#         clr  proportion  count
# 941   beige    0.309621    988
# 949   lilac    0.165465    528
# 952  orange    0.159511    509
# 947   ivory    0.113757    363
# 940    aqua    0.073645    235
#
# Baseline's top colors:
# clr
# cocoa     0.239213
# orange    0.171607
# red       0.142423
# amber     0.108148
# navy      0.091525
# Name: urban+barren, dtype: float64
#
# ============================================================
# LANDCOVER: urban+crop (divergence: 0.714)
# ============================================================
#
# County's top colors:
#         clr  proportion  count
# 956   beige    0.260870      6
# 962  orange    0.217391      5
# 960   lilac    0.130435      3
# 955    aqua    0.086957      2
# 957     foo    0.086957      2
#
# Baseline's top colors:
# clr
# brown         0.145122
# lavender      0.083295
# alabaster     0.081917
# cocoa         0.079543
# terracotta    0.067317
# Name: urban+crop, dtype: float64

# %%
# from eda
clr_bldgtype_distributions = df.groupby(['clr', 'bldgtype'])['clr_cc'].sum().unstack(fill_value=0)
clr_bldgtype_distributions = clr_bldgtype_distributions.div(clr_bldgtype_distributions.sum(axis=1), axis=0)
clr_bldgtype_distributions.columns = ['bldgtype_' + c for c in clr_bldgtype_distributions.columns]
clr_bldgtype_distributions = clr_bldgtype_distributions.reset_index()

clr_damcat_distributions = df.groupby(['clr', 'st_damcat'])['clr_cc'].sum().unstack(fill_value=0)
clr_damcat_distributions = clr_damcat_distributions.div(clr_damcat_distributions.sum(axis=1), axis=0)
clr_damcat_distributions.columns = ['damcat_' + c for c in clr_damcat_distributions.columns]
clr_damcat_distributions = clr_damcat_distributions.reset_index()

clr_lc_distributions = df.groupby(['clr', 'lc_type'])['clr_cc'].sum().unstack(fill_value=0)
clr_lc_distributions = clr_lc_distributions.div(clr_lc_distributions.sum(axis=1), axis=0)
clr_lc_distributions.columns = ['lc_' + c for c in clr_lc_distributions.columns]
clr_lc_distributions = clr_lc_distributions.reset_index()

distributions = clr_bldgtype_distributions.merge(clr_damcat_distributions, on='clr').merge(clr_lc_distributions, on='clr')
distributions = distributions.set_index('clr')

distributions.head()
# Out:
#             bldgtype_C  bldgtype_H  bldgtype_M  bldgtype_S  bldgtype_W  \
# clr
# alabaster     0.001872    0.037555    0.441270    0.002377    0.516926
# amber         0.011349    0.034038    0.439957    0.004668    0.509989
# aqua          0.000556    0.061289    0.426796    0.002318    0.509040
# aquamarine    0.000566    0.048698    0.447339    0.002718    0.500680
# auburn        0.455656    0.004404    0.248248    0.103504    0.188188
#
#             damcat_COM  damcat_IND  damcat_PUB  damcat_RES  lc_barren  ...  \
# clr                                                                    ...
# alabaster     0.000000    0.000000    0.000000    1.000000   0.003884  ...
# amber         0.017830    0.002462    0.001093    0.978615   0.002028  ...
# aqua          0.000000    0.000000    0.000000    1.000000   0.004358  ...
# aquamarine    0.000000    0.000000    0.000000    1.000000   0.022877  ...
# auburn        0.867467    0.119920    0.012613    0.000000   0.000400  ...
#
#             lc_grass  lc_other  lc_shrub  lc_urban  lc_urban+barren  \
# clr
# alabaster   0.006142       0.0  0.021651  0.487036         0.038896
# amber       0.000873       0.0  0.006336  0.600874         0.062445
# aqua        0.003060       0.0  0.069634  0.054242         0.023922
# aquamarine  0.002039       0.0  0.034202  0.024236         0.019479
# auburn      0.000000       0.0  0.000000  0.927327         0.001602
#
#             lc_urban+crop  lc_urban+forest  lc_urban+grass  lc_urban+other  \
# clr
# alabaster        0.073783         0.108839        0.157632        0.000043
# amber            0.052704         0.078198        0.147409        0.000063
# aqua             0.230598         0.133055        0.291701        0.000371
# aquamarine       0.589128         0.036353        0.078143        0.000000
# auburn           0.034835         0.015616        0.011211        0.000000
#
#             lc_urban+shrub
# clr
# alabaster         0.029163
# amber             0.037905
# aqua              0.029393
# aquamarine        0.010759
# auburn            0.008008
#
# [5 rows x 22 columns]

# %%
# find color pairs with high similarity
color_pairs_county_split = []

for i, color1 in enumerate(distributions.index):
    for color2 in distributions.index[i+1:]:
        # check if colors are used in similar contexts
        js_dist = jensenshannon(distributions.loc[color1], distributions.loc[color2])

        if js_dist < 0.15:  # similar context
            # check if different counties use them
            counties1 = set(df[df['clr'] == color1]['fips'].unique())
            counties2 = set(df[df['clr'] == color2]['fips'].unique())

            overlap = len(counties1 & counties2) / len(counties1 | counties2)

            if overlap < 0.3:  # low county overlap
                color_pairs_county_split.append({
                    'color1': color1,
                    'color2': color2,
                    'context_similarity': 1 - js_dist,
                    'county_overlap': overlap,
                    'counties1_only': len(counties1 - counties2),
                    'counties2_only': len(counties2 - counties1)
                })

result_df = pd.DataFrame(color_pairs_county_split).sort_values('context_similarity', ascending=False)
result_df
# Out:
#     color1  color2  context_similarity  county_overlap  counties1_only  \
# 75  purple     red            0.963392        0.250000               8
# 36   brown    sage            0.961585        0.235294               8
# 73  orange     red            0.957688        0.200000              16
# 12   amber  purple            0.950096        0.200000              24
# 41   cocoa  orange            0.946087        0.235294              10
# ..     ...     ...                 ...             ...             ...
# 38   cocoa   green            0.855189        0.296296              10
# 57   ivory     red            0.854948        0.000000              18
# 66   lilac   olive            0.853620        0.200000              16
# 50   green    sage            0.853520        0.000000              17
# 17   azure    gold            0.851914        0.000000               7
#
#     counties2_only
# 75              16
# 36              18
# 73              16
# 12               8
# 41              16
# ..             ...
# 38               9
# 57              24
# 66              24
# 50              26
# 17              21
#
# [77 rows x 6 columns]

# %%
# top 10 most suspicious pairs
top_pairs = result_df.head(10)

for _, row in top_pairs.iterrows():
    c1, c2 = row['color1'], row['color2']

    print(f"\n{'='*70}")
    print(f"{c1.upper()} vs {c2.upper()}")
    print(f"Context similarity: {row['context_similarity']:.3f} (very similar usage)")
    print(f"County overlap: {row['county_overlap']:.3f} (low = different counties)")
    print(f"{'='*70}")

    counties1 = df[df['clr'] == c1]['fips'].unique()
    counties2 = df[df['clr'] == c2]['fips'].unique()

    print(f"\nCounties using {c1}: {sorted(counties1)[:10]}...")
    print(f"Counties using {c2}: {sorted(counties2)[:10]}...")

    # contextual distributions side by side
    print(f"\n{c1} landcover distribution:")
    lc_cols = [c for c in distributions.columns if c.startswith('lc_')]
    print(distributions.loc[c1, lc_cols].nlargest(3))

    print(f"\n{c2} landcover distribution:")
    print(distributions.loc[c2, lc_cols].nlargest(3))
# Out:
# ======================================================================
# PURPLE vs RED
# Context similarity: 0.963 (very similar usage)
# County overlap: 0.250 (low = different counties)
# ======================================================================
#
# Counties using purple: [6001, 6009, 6019, 6025, 6029, 6031, 6055, 6059, 6065, 6067]...
# Counties using red: [6001, 6005, 6013, 6015, 6019, 6021, 6029, 6035, 6059, 6061]...
#
# purple landcover distribution:
# lc_urban          0.683019
# lc_urban+grass    0.106300
# lc_urban+crop     0.063193
# Name: purple, dtype: float64
#
# red landcover distribution:
# lc_urban           0.634876
# lc_urban+grass     0.125709
# lc_urban+barren    0.072439
# Name: red, dtype: float64
#
# ======================================================================
# BROWN vs SAGE
# Context similarity: 0.962 (very similar usage)
# County overlap: 0.235 (low = different counties)
# ======================================================================
#
# Counties using brown: [6007, 6013, 6017, 6053, 6061, 6077, 6079, 6081, 6083, 6087]...
# Counties using sage: [6003, 6011, 6013, 6023, 6027, 6033, 6037, 6039, 6041, 6043]...
#
# brown landcover distribution:
# lc_urban+forest    0.298832
# lc_urban+grass     0.218578
# lc_urban           0.182679
# Name: brown, dtype: float64
#
# sage landcover distribution:
# lc_urban+forest    0.260406
# lc_urban           0.234032
# lc_urban+grass     0.215498
# Name: sage, dtype: float64
#
# ======================================================================
# ORANGE vs RED
# Context similarity: 0.958 (very similar usage)
# County overlap: 0.200 (low = different counties)
# ======================================================================
#
# Counties using orange: [6001, 6003, 6011, 6019, 6023, 6027, 6029, 6033, 6039, 6041]...
# Counties using red: [6001, 6005, 6013, 6015, 6019, 6021, 6029, 6035, 6059, 6061]...
#
# orange landcover distribution:
# lc_urban           0.660474
# lc_urban+grass     0.087412
# lc_urban+barren    0.067269
# Name: orange, dtype: float64
#
# red landcover distribution:
# lc_urban           0.634876
# lc_urban+grass     0.125709
# lc_urban+barren    0.072439
# Name: red, dtype: float64
#
# ======================================================================
# AMBER vs PURPLE
# Context similarity: 0.950 (very similar usage)
# County overlap: 0.200 (low = different counties)
# ======================================================================
#
# Counties using amber: [6001, 6007, 6013, 6017, 6019, 6029, 6033, 6037, 6039, 6041]...
# Counties using purple: [6001, 6009, 6019, 6025, 6029, 6031, 6055, 6059, 6065, 6067]...
#
# amber landcover distribution:
# lc_urban           0.600874
# lc_urban+grass     0.147409
# lc_urban+forest    0.078198
# Name: amber, dtype: float64
#
# purple landcover distribution:
# lc_urban          0.683019
# lc_urban+grass    0.106300
# lc_urban+crop     0.063193
# Name: purple, dtype: float64
#
# ======================================================================
# COCOA vs ORANGE
# Context similarity: 0.946 (very similar usage)
# County overlap: 0.235 (low = different counties)
# ======================================================================
#
# Counties using cocoa: [6001, 6009, 6019, 6025, 6029, 6031, 6037, 6055, 6059, 6065]...
# Counties using orange: [6001, 6003, 6011, 6019, 6023, 6027, 6029, 6033, 6039, 6041]...
#
# cocoa landcover distribution:
# lc_urban           0.695699
# lc_urban+forest    0.097822
# lc_urban+grass     0.061959
# Name: cocoa, dtype: float64
#
# orange landcover distribution:
# lc_urban           0.660474
# lc_urban+grass     0.087412
# lc_urban+barren    0.067269
# Name: orange, dtype: float64
#
# ======================================================================
# ORANGE vs PURPLE
# Context similarity: 0.945 (very similar usage)
# County overlap: 0.250 (low = different counties)
# ======================================================================
#
# Counties using orange: [6001, 6003, 6011, 6019, 6023, 6027, 6029, 6033, 6039, 6041]...
# Counties using purple: [6001, 6009, 6019, 6025, 6029, 6031, 6055, 6059, 6065, 6067]...
#
# orange landcover distribution:
# lc_urban           0.660474
# lc_urban+grass     0.087412
# lc_urban+barren    0.067269
# Name: orange, dtype: float64
#
# purple landcover distribution:
# lc_urban          0.683019
# lc_urban+grass    0.106300
# lc_urban+crop     0.063193
# Name: purple, dtype: float64
#
# ======================================================================
# IVORY vs LILAC
# Context similarity: 0.937 (very similar usage)
# County overlap: 0.294 (low = different counties)
# ======================================================================
#
# Counties using ivory: [6003, 6009, 6011, 6025, 6027, 6031, 6037, 6043, 6049, 6051]...
# Counties using lilac: [6003, 6005, 6007, 6011, 6015, 6017, 6021, 6027, 6035, 6037]...
#
# ivory landcover distribution:
# lc_urban           0.861779
# lc_urban+grass     0.040876
# lc_urban+forest    0.037145
# Name: ivory, dtype: float64
#
# lilac landcover distribution:
# lc_urban           0.793933
# lc_urban+grass     0.058532
# lc_urban+forest    0.054059
# Name: lilac, dtype: float64
#
# ======================================================================
# NAVY vs RED
# Context similarity: 0.932 (very similar usage)
# County overlap: 0.167 (low = different counties)
# ======================================================================
#
# Counties using navy: [6001, 6007, 6009, 6017, 6019, 6023, 6025, 6029, 6031, 6033]...
# Counties using red: [6001, 6005, 6013, 6015, 6019, 6021, 6029, 6035, 6059, 6061]...
#
# navy landcover distribution:
# lc_urban           0.675412
# lc_urban+grass     0.094936
# lc_urban+barren    0.071257
# Name: navy, dtype: float64
#
# red landcover distribution:
# lc_urban           0.634876
# lc_urban+grass     0.125709
# lc_urban+barren    0.072439
# Name: red, dtype: float64
#
# ======================================================================
# IVORY vs LEMON
# Context similarity: 0.929 (very similar usage)
# County overlap: 0.269 (low = different counties)
# ======================================================================
#
# Counties using ivory: [6003, 6009, 6011, 6025, 6027, 6031, 6037, 6043, 6049, 6051]...
# Counties using lemon: [6001, 6011, 6019, 6027, 6029, 6037, 6049, 6051, 6059, 6065]...
#
# ivory landcover distribution:
# lc_urban           0.861779
# lc_urban+grass     0.040876
# lc_urban+forest    0.037145
# Name: ivory, dtype: float64
#
# lemon landcover distribution:
# lc_urban           0.837495
# lc_urban+forest    0.054200
# lc_urban+grass     0.053802
# Name: lemon, dtype: float64
#
# ======================================================================
# INDIGO vs SAGE
# Context similarity: 0.927 (very similar usage)
# County overlap: 0.286 (low = different counties)
# ======================================================================
#
# Counties using indigo: [6001, 6007, 6011, 6017, 6019, 6027, 6029, 6033, 6039, 6041]...
# Counties using sage: [6003, 6011, 6013, 6023, 6027, 6033, 6037, 6039, 6041, 6043]...
#
# indigo landcover distribution:
# lc_urban+forest    0.315241
# lc_urban+grass     0.202556
# lc_urban           0.168081
# Name: indigo, dtype: float64
#
# sage landcover distribution:
# lc_urban+forest    0.260406
# lc_urban           0.234032
# lc_urban+grass     0.215498
# Name: sage, dtype: float64

# %%
# check ivory vs alabaster directly
c1, c2 = 'ivory', 'alabaster'

js_dist = jensenshannon(distributions.loc[c1], distributions.loc[c2])

counties1 = set(df[df['clr'] == c1]['fips'].unique())
counties2 = set(df[df['clr'] == c2]['fips'].unique())
overlap = len(counties1 & counties2) / len(counties1 | counties2)

print(f"IVORY vs ALABASTER")
print(f"Context similarity: {1 - js_dist:.3f}")
print(f"County overlap: {overlap:.3f}")
print(f"\nCounties using ivory only: {len(counties1 - counties2)}")
print(f"Counties using alabaster only: {len(counties2 - counties1)}")
print(f"Counties using both: {len(counties1 & counties2)}")

print(f"\nIvory landcover distribution:")
lc_cols = [c for c in distributions.columns if c.startswith('lc_')]
print(distributions.loc['ivory', lc_cols].nlargest(3))

print(f"\nAlabaster landcover distribution:")
print(distributions.loc['alabaster', lc_cols].nlargest(3))
# Out:
# IVORY vs ALABASTER
# Context similarity: 0.815
# County overlap: 0.000
#
# Counties using ivory only: 18
# Counties using alabaster only: 32
# Counties using both: 0
#
# Ivory landcover distribution:
# lc_urban           0.861779
# lc_urban+grass     0.040876
# lc_urban+forest    0.037145
# Name: ivory, dtype: float64
#
# Alabaster landcover distribution:
# lc_urban           0.487036
# lc_urban+grass     0.157632
# lc_urban+forest    0.108839
# Name: alabaster, dtype: float64

# %%
  # Save divergence scores (county + landcover level)
divergence_df.to_csv('jsd_conditional_divergence.csv', index=False)

  # Save county-level summary
  county_summary.to_csv('jsd_conditional_county_summary.csv', index=False)

  # Save color pairs analysis
  result_df.to_csv('color_pairs_analysis.csv', index=False)

# %%
# Download shapefile
url = "https://www2.census.gov/geo/tiger/GENZ2021/shp/cb_2021_us_county_20m.zip"
urllib.request.urlretrieve(url, "counties.zip")
with zipfile.ZipFile("counties.zip", "r") as z:
    z.extractall("counties")

# Load and aggregate JSD data to county level
df = pd.read_csv('jsd_conditional_divergence.csv')
county_jsd = df.groupby('fips')['divergence'].mean().reset_index()
county_jsd.columns = ['fips', 'mean_jsd']
county_jsd['fips'] = county_jsd['fips'].astype(str).str.zfill(5)

# Load shapefile and filter to CA
gdf = gpd.read_file("counties/cb_2021_us_county_20m.shp")
gdf = gdf[gdf['STATEFP'] == '06'].copy()
gdf['fips'] = gdf['GEOID']

# Merge
gdf = gdf.merge(county_jsd, on='fips', how='left')

# Plot
cmap = LinearSegmentedColormap.from_list('jsd', ['#ffffcc', '#fd8d3c', '#e31a1c', '#67000d'])

fig, ax = plt.subplots(1, 1, figsize=(10, 10))
gdf.plot(
    column='mean_jsd',
    ax=ax,
    cmap=cmap,
    edgecolor='black',
    linewidth=0.3,
    legend=True,
    legend_kwds={'label': 'Mean JSD (vs statewide baseline)'}
)
ax.set_title('County-Level Mean JSD vs. Statewide Baseline', fontsize=16, y=0.92)
ax.axis('off')
plt.tight_layout()
plt.savefig('county_jsd_baseline_map.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
